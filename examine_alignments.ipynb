# %%
import pandas as pd
import utils.db_utils as db
import utils.file_utils as file
import utils.bible_utils as bible

original_words_table = db.original_words_table
target_words_table = db.target_words_table
alignment_table = db.alignment_table
dbPath = './data/alignmentsData.sqlite'
origLangPathGreek = './data/OrigLangJson/ugnt/v0.14'
origLangPathHebrew = './data/OrigLangJson/uhb/v2.1.15'

connection = db.initAlignmentDB(dbPath)

items_target = db.fetchRecords(connection, target_words_table, '')
print (f"{len(items_target)} items in target_words_table")

items_align = db.fetchRecords(connection, alignment_table, '')
print (f"{len(items_align)} items in alignment_table")

items_orig = db.fetchRecords(connection, original_words_table, '')
print (f"{len(items_orig)} items in original_words_table")

# 69050 items in target_words_table
# 48892 items in alignment_table
# 52996 items in original_words_table

searchOriginal = True
searchTarget = False
searchLemma = True
caseInsensitive = True
# Out:
# Connection to SQLite DB successful
# 69522 items in target_words_table
# 47476 items in alignment_table
# 357007 items in original_words_table

# %%
# find exact word Θεοῦ in original language
godAlignments = db.findAlignmentsForWord(connection, 'Θεοῦ', searchOriginal)
# frequency of alignments
frequency = godAlignments['alignmentTxt'].value_counts()
frequency
# Out:
# 262 items in search
# Θεοῦ = God            138
# Θεοῦ = of God          40
# τοῦ Θεοῦ = God         39
# τοῦ Θεοῦ = of God      34
# τοῦ Θεοῦ = God s        2
# Θεοῦ = by God           1
# Θεοῦ = God s            1
# Θεοῦ = between God      1
# τοῦ Θεοῦ = for God      1
# Θεοῦ = of a god         1
# Name: alignmentTxt, dtype: int64

# %%
# find all forms of θεός in original language by lemma
godAlignments = db.findAlignmentsForWord(connection, 'θεός', searchOriginal, searchLemma)
# frequency of alignments
frequency = godAlignments['alignmentTxt'].value_counts()
frequency
# Out:
# 509 items in search
# Θεοῦ = God             138
# ὁ Θεὸς = God            80
# Θεοῦ = of God           40
# τοῦ Θεοῦ = God          39
# τὸν Θεόν = God          37
# τοῦ Θεοῦ = of God       34
# τὸν Θεὸν = God          22
# Θεῷ = God               21
# Θεὸς = God              18
# τῷ Θεῷ = God            14
# ὁ Θεός = God            12
# Θεὸν = God               9
# τῷ Θεῷ = to God          6
# Θεὸς = the God           3
# Θεῷ = the God            2
# Θεὸν = the God           2
# θεοὶ = gods              2
# τοῦ Θεοῦ = God s         2
# Θεόν = God               2
# ὁ δὲ Θεός = But God      1
# θεὸν = goddess           1
# θεοῦ = god               1
# Θεοῦ = God s             1
# θεοὺς = gods             1
# ὁ Θεὸς = god is          1
# ὁ Θεός = God is          1
# Θεοῦ = between God       1
# θεοῖς = gods             1
# Θεός = God               1
# Θεοῦ = of a god          1
# ὁ Θεὸς = but God         1
# Θεῷ = with God           1
# Θεοῦ = by God            1
# θεοῦ = God               1
# τοῦ Θεοῦ = for God       1
# Θεῷ = an God             1
# ὅτι ὁ Θεὸς = God         1
# Θεῷ = to God             1
# θεόν = a god             1
# Θεὸν = a God             1
# Name: alignmentTxt, dtype: int64

# %%
# find exact word 'God' in target language
godAlignments = db.findAlignmentsForWord(connection, 'God', searchTarget)
# frequency of alignments
frequency = godAlignments['alignmentTxt'].value_counts()
frequency
# Out:
# 524 items in search
# Θεοῦ = God                                 138
# ὁ Θεὸς = God                                80
# Θεοῦ = of God                               40
# τοῦ Θεοῦ = God                              39
# τὸν Θεόν = God                              37
# τοῦ Θεοῦ = of God                           34
# τὸν Θεὸν = God                              22
# Θεῷ = God                                   21
# Θεὸς = God                                  18
# τῷ Θεῷ = God                                14
# ὁ Θεός = God                                12
# Θεὸν = God                                   9
# τῷ Θεῷ = to God                              6
# Θεὸς = the God                               3
# τοῦ Θεοῦ = God s                             2
# Θεῷ = the God                                2
# Θεὸν = the God                               2
# Θεόν = God                                   2
# λατρεῦον = as they worship God               1
# τοῦ Θεοῦ = for God                           1
# ὁ δὲ Θεός = But God                          1
# μετῴκισεν = God brought                      1
# ὁ = God                                      1
# Θεοῦ = God s                                 1
# δώσει = God will give                        1
# αὐτοῦ = God s                                1
# ὁ Θεός = God is                              1
# Θεῷ = an God                                 1
# θεομάχοι = you are fighting against God      1
# Θεοῦ = between God                           1
# αὐτὸς = God                                  1
# αὐτῷ = God                                   1
# Θεός = God                                   1
# Θεὸν = a God                                 1
# σεβομένοις = worshiped God                   1
# ὁ Θεὸς = but God                             1
# ἐξέχεεν = God poured                         1
# Θεῷ = with God                               1
# Θεοῦ = by God                                1
# θεοῦ = God                                   1
# ἄθεοι = without God                          1
# ἔδωκεν = God gave                            1
# ὅτι ὁ Θεὸς = God                             1
# Θεῷ = to God                                 1
# αὐτὸν = God                                  1
# Name: alignmentTxt, dtype: int64

# %%
godAlignments.describe()
# Out:
#                   id  alignment_num    origSpan  alignmentOrigWords  \
# count     508.000000     508.000000  508.000000          508.000000
# mean   146533.259843      10.326772    0.511811            1.498031
# std     14291.086315       6.100370    0.534655            0.508310
# min    118054.000000       0.000000    0.000000            1.000000
# 25%    136841.500000       6.000000    0.000000            1.000000
# 50%    146983.000000       9.000000    0.000000            1.000000
# 75%    159553.000000      15.000000    1.000000            2.000000
# max    165402.000000      27.000000    2.000000            3.000000
#
#        targetSpan  alignmentTargetWords   frequency
# count  508.000000            508.000000  508.000000
# mean     0.344488              1.226378    0.127286
# std      1.205440              0.463599    0.098157
# min      0.000000              1.000000    0.001969
# 25%      0.000000              1.000000    0.043307
# 50%      0.000000              1.000000    0.078740
# 75%      0.000000              1.000000    0.271654
# max     18.000000              5.000000    0.271654

# %%
# find word (ignore case) in target language
godAlignments = db.findAlignmentsForWord(connection, 'God', searchTarget, False, caseInsensitive)
frequency = godAlignments['alignmentTxt'].value_counts()
frequency
# Out:
# 528 items in search
# Θεοῦ = God                                 138
# ὁ Θεὸς = God                                80
# Θεοῦ = of God                               40
# τοῦ Θεοῦ = God                              39
# τὸν Θεόν = God                              37
# τοῦ Θεοῦ = of God                           34
# τὸν Θεὸν = God                              22
# Θεῷ = God                                   21
# Θεὸς = God                                  18
# τῷ Θεῷ = God                                14
# ὁ Θεός = God                                12
# Θεὸν = God                                   9
# τῷ Θεῷ = to God                              6
# Θεὸς = the God                               3
# τοῦ Θεοῦ = God s                             2
# Θεῷ = the God                                2
# Θεόν = God                                   2
# Θεὸν = the God                               2
# Θεοῦ = God s                                 1
# ὁ δὲ Θεός = But God                          1
# τοῦ Θεοῦ = for God                           1
# ὁ Θεός = God is                              1
# λατρεῦον = as they worship God               1
# Θεῷ = an God                                 1
# θεοῦ = god                                   1
# ὁ Θεὸς = god is                              1
# ὁ = God                                      1
# μετῴκισεν = God brought                      1
# αὐτοῦ = God s                                1
# θεομάχοι = you are fighting against God      1
# δώσει = God will give                        1
# Θεῷ = with God                               1
# θεόν = a god                                 1
# Θεῷ = to God                                 1
# ὅτι ὁ Θεὸς = God                             1
# ἔδωκεν = God gave                            1
# ἄθεοι = without God                          1
# θεοῦ = God                                   1
# Θεοῦ = by God                                1
# ἐξέχεεν = God poured                         1
# Θεοῦ = between God                           1
# ὁ Θεὸς = but God                             1
# Θεοῦ = of a god                              1
# σεβομένοις = worshiped God                   1
# Θεὸν = a God                                 1
# αὐτὸν = God                                  1
# Θεός = God                                   1
# αὐτὸς = God                                  1
# αὐτῷ = God                                   1
# Name: alignmentTxt, dtype: int64

# %%
godAlignments.isnull().values.any()
# Out:
# False

# %%
godAlignments.describe()
# Out:
#                   id  alignment_num    origSpan  alignmentOrigWords  \
# count     512.000000     512.000000  512.000000          512.000000
# mean   146550.025391      10.332031    0.509766            1.496094
# std     14250.928866       6.128684    0.534433            0.508234
# min    118054.000000       0.000000    0.000000            1.000000
# 25%    136851.000000       6.000000    0.000000            1.000000
# 50%    146983.000000       9.000000    0.000000            1.000000
# 75%    159515.500000      15.000000    1.000000            2.000000
# max    165402.000000      27.000000    2.000000            3.000000
#
#        targetSpan  alignmentTargetWords   frequency
# count  512.000000            512.000000  512.000000
# mean     0.349609              1.232422    0.125320
# std      1.203729              0.470961    0.097625
# min      0.000000              1.000000    0.001953
# 25%      0.000000              1.000000    0.042969
# 50%      0.000000              1.000000    0.078125
# 75%      0.000000              1.000000    0.269531
# max     18.000000              5.000000    0.269531

# %%
godAlignments
# Out:
#          id book_id chapter verse  alignment_num  orig_lang_words  \
# 0    118054     luk       1     6              5  ,750353,750354,
# 1    118093     luk       1     8             12  ,750396,750397,
# 2    118206     luk       1    16              8  ,750517,750518,
# 3    118262     luk       1    19             11  ,750579,750580,
# 4    118382     luk       1    26             10  ,750709,750710,
# ..      ...     ...     ...   ...            ...              ...
# 507  165087     2jn       1     3              7         ,801721,
# 508  165188     2jn       1     9              9         ,801838,
# 509  165319     3jn       1     6             12         ,801998,
# 510  165396     3jn       1    11             11  ,802076,802077,
# 511  165402     3jn       1    11             17  ,802083,802084,
#
#     target_lang_words  origSpan  \
# 0            ,727232,         1
# 1            ,727274,         1
# 2            ,727452,         1
# 3            ,727539,         1
# 4            ,727714,         1
# ..                ...       ...
# 507          ,796060,         0
# 508          ,796230,         0
# 509          ,796439,         0
# 510          ,796557,         1
# 511          ,796566,         1
#
#                                              origWords origWordsTxt  \
# 0    [{'id': 750353, 'book_id': 'luk', 'chapter': '...     τοῦ Θεοῦ
# 1    [{'id': 750396, 'book_id': 'luk', 'chapter': '...     τοῦ Θεοῦ
# 2    [{'id': 750517, 'book_id': 'luk', 'chapter': '...     τὸν Θεὸν
# 3    [{'id': 750579, 'book_id': 'luk', 'chapter': '...     τοῦ Θεοῦ
# 4    [{'id': 750709, 'book_id': 'luk', 'chapter': '...     τοῦ Θεοῦ
# ..                                                 ...          ...
# 507  [{'id': 801721, 'book_id': '2jn', 'chapter': '...         Θεοῦ
# 508  [{'id': 801838, 'book_id': '2jn', 'chapter': '...         Θεὸν
# 509  [{'id': 801998, 'book_id': '3jn', 'chapter': '...         Θεοῦ
# 510  [{'id': 802076, 'book_id': '3jn', 'chapter': '...     τοῦ Θεοῦ
# 511  [{'id': 802083, 'book_id': '3jn', 'chapter': '...     τὸν Θεόν
#
#      alignmentOrigWords  targetSpan  \
# 0                     2           0
# 1                     2           0
# 2                     2           0
# 3                     2           0
# 4                     2           0
# ..                  ...         ...
# 507                   1           0
# 508                   1           0
# 509                   1           0
# 510                   2           0
# 511                   2           0
#
#                                            targetWords targetWordsTxt  \
# 0    [{'id': 727232, 'book_id': 'luk', 'chapter': '...            God
# 1    [{'id': 727274, 'book_id': 'luk', 'chapter': '...            God
# 2    [{'id': 727452, 'book_id': 'luk', 'chapter': '...            God
# 3    [{'id': 727539, 'book_id': 'luk', 'chapter': '...            God
# 4    [{'id': 727714, 'book_id': 'luk', 'chapter': '...            God
# ..                                                 ...            ...
# 507  [{'id': 796060, 'book_id': '2jn', 'chapter': '...            God
# 508  [{'id': 796230, 'book_id': '2jn', 'chapter': '...            God
# 509  [{'id': 796439, 'book_id': '3jn', 'chapter': '...            God
# 510  [{'id': 796557, 'book_id': '3jn', 'chapter': '...            God
# 511  [{'id': 796566, 'book_id': '3jn', 'chapter': '...            God
#
#      alignmentTargetWords    alignmentTxt  frequency
# 0                       1  τοῦ Θεοῦ = God   0.076172
# 1                       1  τοῦ Θεοῦ = God   0.076172
# 2                       1  τὸν Θεὸν = God   0.042969
# 3                       1  τοῦ Θεοῦ = God   0.076172
# 4                       1  τοῦ Θεοῦ = God   0.076172
# ..                    ...             ...        ...
# 507                     1      Θεοῦ = God   0.269531
# 508                     1      Θεὸν = God   0.017578
# 509                     1      Θεοῦ = God   0.269531
# 510                     1  τοῦ Θεοῦ = God   0.076172
# 511                     1  τὸν Θεόν = God   0.072266
#
# [512 rows x 17 columns]

# %%
godAlignments = db.findAlignmentsForWord(connection, 'θεός', True, True)
# Out:
# 509 items in search

# %%
godAlignments.describe()
# Out:
#                   id  alignment_num    origSpan  alignmentOrigWords  \
# count     504.000000     504.000000  504.000000          504.000000
# mean   146347.807540      10.422619    0.517857            1.503968
# std     14221.867386       6.103316    0.534755            0.508364
# min    118054.000000       0.000000    0.000000            1.000000
# 25%    136828.000000       6.000000    0.000000            1.000000
# 50%    146855.500000       9.500000    0.500000            1.500000
# 75%    159140.500000      15.000000    1.000000            2.000000
# max    165402.000000      27.000000    2.000000            3.000000
#
#        targetSpan  alignmentTargetWords   frequency
# count  504.000000            504.000000  504.000000
# mean     0.319444              1.206349    0.129307
# std      1.177632              0.409965    0.098672
# min      0.000000              1.000000    0.001984
# 25%      0.000000              1.000000    0.043651
# 50%      0.000000              1.000000    0.079365
# 75%      0.000000              1.000000    0.273810
# max     18.000000              3.000000    0.273810
