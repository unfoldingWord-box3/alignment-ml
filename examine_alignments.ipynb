# %%
import pandas as pd
import utils.db_utils as db
import utils.file_utils as file
import utils.bible_utils as bible

original_words_table = db.original_words_table
target_words_table = db.target_words_table
alignment_table = db.alignment_table
dbPath = './data/alignmentData.sqlite'
origLangPathGreek = './data/OrigLangJson/ugnt/v0.14'
origLangPathHebrew = './data/OrigLangJson/uhb/v2.1.15'

connection = db.initAlignmentDB(dbPath)

bibleType = 'en_ult'
testament = 1
dataFolder = './data/Alignments'
bookId = 'tit'
# Out:
# Connection to SQLite DB successful

# %%
items_target = db.fetchRecords(connection, target_words_table, '')
print (f"{len(items_target)} items in target_words_table")

items_align = db.fetchRecords(connection, alignment_table, '')
print (f"{len(items_align)} items in alignment_table")

items_orig = db.fetchRecords(connection, original_words_table, '')
print (f"{len(items_orig)} items in original_words_table")

# 69050 items in target_words_table
# 48892 items in alignment_table
# 52996 items in original_words_table

lemma = 'θεός'
word = 'Θεοῦ'

# find all forms of word by lemma
lemmas = db.findOriginalLemma(connection, lemma)
print (f"{len(lemmas)} items found")

# find specific word by text
words = db.findOriginalWord(connection, word)
print (f"{len(words)} items in search")

first_word = words[0]

# item = db.findWordById(connection, 75, original_words_table)

alignment = db.getAlignmentForWord(connection, first_word, 1)

alignments = db.getAlignmentsForWord(connection, words, 1)

# load as dataframe
df = pd.DataFrame(alignments)
# Out:
# 69050 items in target_words_table
# 48892 items in alignment_table
# 51861 items in original_words_table
# 509 items found
# 262 items in search: word = 'Θεοῦ'
# 262 items in search

# %%
df
# Out:
#         id book_id chapter verse  alignment_num orig_lang_words  \
# 0       74     luk       1     6              5         ,75,76,
# 1      113     luk       1     8             12       ,118,119,
# 2      284     luk       1    19             11       ,301,302,
# 3      404     luk       1    26             10       ,431,432,
# 4      546     luk       1    35             22           ,581,
# ..     ...     ...     ...   ...            ...             ...
# 257  48409     1jn       5    19              3   ,51346,51347,
# 258  48422     1jn       5    20              5   ,51362,51363,
# 259  48494     2jn       1     3              7         ,51443,
# 260  48755     3jn       1     6             12         ,51720,
# 261  48832     3jn       1    11             11   ,51798,51799,
#
#     target_lang_words                                          origWords  \
# 0               ,115,  [{'id': 75, 'book_id': 'luk', 'chapter': '1', ...
# 1               ,163,  [{'id': 118, 'book_id': 'luk', 'chapter': '1',...
# 2               ,415,  [{'id': 301, 'book_id': 'luk', 'chapter': '1',...
# 3               ,590,  [{'id': 431, 'book_id': 'luk', 'chapter': '1',...
# 4           ,796,797,  [{'id': 581, 'book_id': 'luk', 'chapter': '1',...
# ..                ...                                                ...
# 257           ,68361,  [{'id': 51346, 'book_id': '1jn', 'chapter': '5...
# 258     ,68385,68386,  [{'id': 51362, 'book_id': '1jn', 'chapter': '5...
# 259           ,68481,  [{'id': 51443, 'book_id': '2jn', 'chapter': '1...
# 260           ,68850,  [{'id': 51720, 'book_id': '3jn', 'chapter': '1...
# 261           ,68967,  [{'id': 51798, 'book_id': '3jn', 'chapter': '1...
#
#     origWordsTxt                                        targetWords  \
# 0       τοῦ Θεοῦ  [{'id': 115, 'book_id': 'luk', 'chapter': '1',...
# 1       τοῦ Θεοῦ  [{'id': 163, 'book_id': 'luk', 'chapter': '1',...
# 2       τοῦ Θεοῦ  [{'id': 415, 'book_id': 'luk', 'chapter': '1',...
# 3       τοῦ Θεοῦ  [{'id': 590, 'book_id': 'luk', 'chapter': '1',...
# 4           Θεοῦ  [{'id': 796, 'book_id': 'luk', 'chapter': '1',...
# ..           ...                                                ...
# 257     τοῦ Θεοῦ  [{'id': 68361, 'book_id': '1jn', 'chapter': '5...
# 258     τοῦ Θεοῦ  [{'id': 68385, 'book_id': '1jn', 'chapter': '5...
# 259         Θεοῦ  [{'id': 68481, 'book_id': '2jn', 'chapter': '1...
# 260         Θεοῦ  [{'id': 68850, 'book_id': '3jn', 'chapter': '1...
# 261     τοῦ Θεοῦ  [{'id': 68967, 'book_id': '3jn', 'chapter': '1...
#
#     targetWordsTxt
# 0              God
# 1              God
# 2              God
# 3              God
# 4           of God
# ..             ...
# 257            God
# 258         of God
# 259            God
# 260            God
# 261            God
#
# [262 rows x 11 columns]
